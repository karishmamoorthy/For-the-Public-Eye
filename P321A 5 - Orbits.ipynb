# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib nbagg

# %%
def orbit(r0, v0, dO = 1e4):
    O0 = np.pi/2
    l = r0*v0*np.sin(O0) #r0 perpendicular v0
    
    G = 6.67*10**(-11)
    M = 5.972*10**(24) #Mass of Earth, Wikipedia
    
    E = 0.5*l*l/(r0*r0) - G*M/r0 + 0.5*v0*v0  #Total energy DIVIDED BY MASS OF OBJECT
    
    e = np.sqrt(1 + (2*E*l*l)/(G*G*M*M)) #Eccentricity of orbit
    a = -1*G*M/(2*E)
    
    print("E/m = ", E)
    print("e = ", e)
    
    O = np.linspace(0, 2*np.pi, dO) #Angles    
    
    r = (1 - e**2)*a/(1 + e*np.cos(O - O0))
    
    #O = []
    #r = []
    #r.append(r0)
    #O.append(O0)
    
    #c = 0
    #O0 = O[c]
    #r0 = (1 - e**2)*a
    
    
    #def solver(r0, O0, c):
     #   r1 = r0 + np.sqrt((E*r0**4 - 0.5*l*l*r0**2 + G*M*r0**3)*2)*dO/l
        
        #O1 = O0 + dO
        #O.append(O1)
        #O0 = O1
        
      #  r0 = r1
       
      #  c += 1
        
        #if c > 500:
         #   return None
        #else:
         #   return solver(r0, O0, c)
        
        
      #  if c == len(O):
      #      return None
      #  else:
      #      r.append(r0)
      #      O0 = O[c]
      #      return solver(r0, O0, c)
    
    #solver(r0, O0, c)

    O = np.array(O)
    r = np.array(r)
    
    x = r*np.cos(O)
    y = r*np.sin(O)
    
    xcircle = r0*np.cos(O)
    ycircle = r0*np.sin(O)
    
    return x, y, xcircle, ycircle

# %%
a1 = orbit(5*10**5, 7468)
a2 = orbit(5*10**5, 7600)
a3 = orbit(5*10**5, 10000)

b1 = orbit(3.3*10**7, 100)
b2 = orbit(3.3*10**7, 1000)
b3 = orbit(3.3*10**7, 4000)

c1 = orbit(3.63*10**8, 500)
c2 = orbit(3.63*10**8, 800)
c3 = orbit(3.63*10**8, 1200)
# Out:
# E/m =  -740893776.0
# e =  0.932625493147
# E/m =  -738904800.0
# e =  0.930327164018
# E/m =  -696664800.0
# e =  0.883439634441
# E/m =  -12060678.7879
# e =  0.999171889628
# E/m =  -11070678.7879
# e =  0.920888674038
# E/m =  3929321.21212
# e =  1.36491272405
# E/m =  -847334.435262
# e =  0.805083025067
# E/m =  -457334.435262
# e =  0.71683677539
# E/m =  342665.564738
# e =  1.34891359654
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
#   app.launch_new_instance()

# %%
a1[0]
# Out:
# array([ 35002.816743  ,  34982.30864467,  34961.81075846, ...,
#         35043.86361549,  35023.33506332,  35002.816743  ])

# %%
fig, ax = plt.subplots()
ax.set_aspect('equal')

plt.plot(a1[0], a1[1], 'b--', label= 'v0 = 7468 m/s')
plt.plot(a2[0], a2[1], 'g--', label= 'v0 = 7600 m/s')
plt.plot(a3[0], a3[1], 'k-', label= 'v0 = 10000 m/s')
plt.plot(a1[2], a1[3], 'r--', label= 'Circular orbit')

plt.legend(fontsize = 7)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('Orbit for r0 = 500km, v0 = 7468, 7600, 10000 m/s')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax = plt.subplots()
ax.set_aspect('equal')

plt.plot(b1[0], b1[1], 'b--', label= 'v0 = 100 m/s')
plt.plot(b2[0], b2[1], 'g--', label= 'v0 = 1000 m/s')
plt.plot(b3[0][0:5500], b3[1][0:5500], 'k-', label= 'v0 = 4000 m/s')
plt.plot(b1[2], b1[3], 'r--', label= 'Circular orbit')

plt.legend(fontsize = 7)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('Orbit for r0 = 33000km, v0 = 100, 1000, 4000 m/s')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax = plt.subplots()
ax.set_aspect('equal')

plt.plot(c1[0], c1[1], 'b--', label= 'v0 = 500 m/s')
plt.plot(c2[0], c2[1], 'g--', label= 'v0 = 800 m/s')
plt.plot(c3[0][0:5500], c3[1][0:5500], 'k-', label= 'v0 = 1200 m/s')
plt.plot(c1[2], c1[3], 'r--', label= 'Circular orbit')

plt.legend(fontsize = 7)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('Orbit for r0 = 363000km, v0 = 500, 800, 1200 m/s')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
